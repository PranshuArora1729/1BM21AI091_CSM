# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-10,10,10000)
y=x**2 + 2*x + 2
fig, ax=plt.subplots()
a=ax.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.set_xlim([-2,-1])
ax.set_ylim([0,2])
a= ax.plot(x,y)
